# %%
# !python -m pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
cliente = MongoClient('mongodb+srv://englpcruz:Euteamo!22@clusterfatec.v0pjc3j.mongodb.net/')

# %%
db = cliente.get_database('marcas')

# %%
novos_carros= [{
  "_id": {
    "$oid": "65160134c35769b237fff280"
  },
  "marca": "Toyota",
  "modelo": "Yares",
  "anofabricacao": 2024,
  "quilometragemrodada": 10000
},{
  "_id": {
    "$oid": "65160134c35769b237fff281"
  },
  "marca": "Honda",
  "modelo": "Cyt",
  "anofabricacao": 2021,
  "quilometragemrodada": 15000
},{
  "_id": {
    "$oid": "65160134c35769b237fff282"
  },
  "marca": "Ford",
  "modelo": "KA",
  "anofabricacao": 2023,
  "quilometragemrodada": 15000
},{
  "_id": {
    "$oid": "65160134c35769b237fff283"
  },
  "marca": "Chevrolet",
  "modelo": "Celta",
  "anofabricacao": 2022,
  "quilometragemrodada": 12000
}]

# %%
db.Carros.insert_many(novos_carros)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-99-a3ab547da7a1> in <cell line: 1>()
# ----> 1 db.Carros.insert_many(novos_carros)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     105                 with _TimeoutContext(timeout):
#     106                     return func(self, *args, **kwargs)
# --> 107         return func(self, *args, **kwargs)
#     108
#     109     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754         blk.ops = list(gen())
# --> 755         blk.execute(write_concern, session=session)
# ...

# %%
consulta_carros = list(db.Carros.find())
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-100-6ef9a7065355> in <cell line: 1>()
# ----> 1 consulta_carros = list(db.Carros.find())
#
# /usr/local/lib/python3.10/dist-packages/pymongo/cursor.py in next(self)
#    1262         if self.__empty:
#    1263             raise StopIteration
# -> 1264         if len(self.__data) or self._refresh():
#    1265             return self.__data.popleft()
#    1266         else:
#
# /usr/local/lib/python3.10/dist-packages/pymongo/cursor.py in _refresh(self)
#    1179                 self.__exhaust,
#    1180             )
# -> 1181             self.__send_message(q)
#    1182         elif self.__id:  # Get More
#    1183             if self.__limit:
#
# /usr/local/lib/python3.10/dist-packages/pymongo/cursor.py in __send_message(self, operation)
#    1058
#    1059         try:
# ...

# %%
db.Carros.count_documents({})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-101-ddfbf379be43> in <cell line: 1>()
# ----> 1 db.Carros.count_documents({})
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in count_documents(self, filter, session, comment, **kwargs)
#    1911             return result["n"]
#    1912
# -> 1913         return self._retryable_non_cursor_read(_cmd, session)
#    1914
#    1915     def _retryable_non_cursor_read(
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in _retryable_non_cursor_read(self, func, session)
#    1921         client = self.__database.client
#    1922         with client._tmp_session(session) as s:
# -> 1923             return client._retryable_read(func, self._read_preference_for(s), s)
#    1924
#    1925     def create_indexes(
#
# ...

# %%
qtde_documentos = db.Carros.count_documents({})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-94-00bbad6bb39e> in <cell line: 1>()
# ----> 1 qtde_documentos = db.Salario.count_documents({})
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in count_documents(self, filter, session, comment, **kwargs)
#    1911             return result["n"]
#    1912
# -> 1913         return self._retryable_non_cursor_read(_cmd, session)
#    1914
#    1915     def _retryable_non_cursor_read(
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in _retryable_non_cursor_read(self, func, session)
#    1921         client = self.__database.client
#    1922         with client._tmp_session(session) as s:
# -> 1923             return client._retryable_read(func, self._read_preference_for(s), s)
#    1924
#    1925     def create_indexes(
#
# ...
